# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\Admin\Documents\Python Folder\fastapi_backend\synthetic_data\face_analytics_small_data.csv')

# %%
data['day']= pd.to_datetime(data['first_seen']).dt.day
